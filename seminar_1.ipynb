# %%
# !git clone https://github.com/Feqqf/Machine_learning_colab.git
# %cd Machine_learning_colab
# Out:
# Cloning into 'Machine_learning_colab'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 16 (delta 5), reused 12 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 628.60 KiB | 9.52 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/Machine_learning_colab/Machine_learning_colab

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Загрузим данные и посмотрим на небольшую часть
data = pd.read_csv('./AppleStore.csv')
data.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# 0          4.0              4.5   6.3.5          4+         Games
# 1          4.0              3.5   8.2.2          4+  Productivity
# 2          3.5              4.5   5.0.0          4+       Weather
# 3          4.0              4.5  5.10.0         12+      Shopping
# 4          4.5              5.0   7.5.1          4+     Reference
#
#    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0               38                5        10        1
# 1               37                5        23        1
# 2               37                5         3        1
# 3               37                5         9        1
# 4               37                5        45        1

# %%
num_cols = [
    'size_bytes',
    'price',
    'rating_count_tot',
    'rating_count_ver',
    'sup_devices.num',
    'ipadSc_urls.num',
    'lang.num',
    # Эта фича - не числовая, а порядковая, но мы все равно возьмем ее как числовую для удобства
    'cont_rating',
]

cat_cols = [
    'currency',
    'prime_genre'
]

target_col = 'user_rating'

cols = num_cols + cat_cols + [target_col]

# %%
data = data[cols]
# Возраст записан не в виде числа, исправим это, вырезав последний символ и скастовав к числу
data['cont_rating'] = data['cont_rating'].str.slice(0, -1).astype(int)
data.head()
# Out:
#    size_bytes  price  rating_count_tot  rating_count_ver  sup_devices.num  \
# 0   100788224   3.99             21292                26               38
# 1   158578688   0.00            161065                26               37
# 2   100524032   0.00            188583              2822               37
# 3   128512000   0.00            262241               649               37
# 4    92774400   0.00            985920              5320               37
#
#    ipadSc_urls.num  lang.num  cont_rating currency   prime_genre  user_rating
# 0                5        10            4      USD         Games          4.0
# 1                5        23            4      USD  Productivity          4.0
# 2                5         3            4      USD       Weather          3.5
# 3                5         9           12      USD      Shopping          4.0
# 4                5        45            4      USD     Reference          4.5

# %%
#Посморим пропущенные значения
data.isna().mean()
# Out:
# size_bytes          0.0
# price               0.0
# rating_count_tot    0.0
# rating_count_ver    0.0
# sup_devices.num     0.0
# ipadSc_urls.num     0.0
# lang.num            0.0
# cont_rating         0.0
# currency            0.0
# prime_genre         0.0
# user_rating         0.0
# dtype: float64

# %%
# Посмотрим на распределение категориальных фичей
for col in cat_cols:
    print(f"{col} DISTRIBUTION")
    print(data[col].value_counts())
    print()
# Out:
# currency DISTRIBUTION
# currency
# USD    7197
# Name: count, dtype: int64
#
# prime_genre DISTRIBUTION
# prime_genre
# Games                3862
# Entertainment         535
# Education             453
# Photo & Video         349
# Utilities             248
# Health & Fitness      180
# Productivity          178
# Social Networking     167
# Lifestyle             144
# Music                 138
# Shopping              122
# Sports                114
# Book                  112
# Finance               104
# Travel                 81
# News                   75
# Weather                72
# Reference              64
# Food & Drink           63
# Business               57
# Navigation             46
# Medical                23
# Catalogs               10
# Name: count, dtype: int64

# %%
# Как мы видим, в колонке currency только одно значение, можно колонку убрать
data = data.drop(columns=['currency'])
cat_cols.remove('currency')

# %%
# Посмотрим на распредление величин
data.hist(column=num_cols+cat_cols+[target_col], figsize=(14, 10))
None

# %%
#Посмотрим на корреляцию
data.corr(numeric_only=True).style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_50722_row0_col0, #T_50722_row1_col1, #T_50722_row2_col2, #T_50722_row3_col3, #T_50722_row4_col4, #T_50722_row5_col5, #T_50722_row6_col6, #T_50722_row7_col7, #T_50722_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_50722_row0_col1, #T_50722_row1_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_50722_row0_col2, #T_50722_row5_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_50722_row0_col3, #T_50722_row4_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_50722_row0_col4, #T_50722_row1_col2, #T_50722_row1_col3, #T_50722_row1_col4, #T_50722_row4_col0, #T_50722_row4_col1, #T_50722_row5_col7, #T_50722_row7_col5, #T_50722_row7_col6, #T_50722_row7_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_50722_row0_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_50722_row0_col6, #T_50722_row2_col1, #T_50722_row6_col4, #T_50722_row8_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_50722_row0_col7, #T_50722_row8_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_50722_row0_col8, #T_50722_row3_col8 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_50722_row1_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_50722_row1_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_50722_row1_col7, #T_50722_row5_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_50722_row1_col8 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_50722_row2_col0, #T_50722_row2_col5, #T_50722_row3_col0, #T_50722_row6_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_50722_row2_col3, #T_50722_row6_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_50722_row2_col4, #T_50722_row4_col7 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_50722_row2_col6, #T_50722_row3_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_50722_row2_col7 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_50722_row2_col8, #T_50722_row8_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_50722_row3_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_50722_row3_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_50722_row3_col5, #T_50722_row8_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_50722_row3_col6, #T_50722_row7_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_50722_row3_col7 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_50722_row4_col2, #T_50722_row7_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_50722_row4_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_50722_row4_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_50722_row4_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_50722_row5_col0, #T_50722_row6_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_50722_row5_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_50722_row5_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_50722_row5_col6, #T_50722_row8_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_50722_row5_col8 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_50722_row6_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_50722_row6_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_50722_row6_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_50722_row6_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_50722_row7_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_50722_row7_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_50722_row7_col4 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_50722_row8_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_50722_row8_col5 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_50722_row8_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_50722" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50722_level0_col0" class="col_heading level0 col0" >size_bytes</th>
#       <th id="T_50722_level0_col1" class="col_heading level0 col1" >price</th>
#       <th id="T_50722_level0_col2" class="col_heading level0 col2" >rating_count_tot</th>
#       <th id="T_50722_level0_col3" class="col_heading level0 col3" >rating_count_ver</th>
#       <th id="T_50722_level0_col4" class="col_heading level0 col4" >sup_devices.num</th>
#       <th id="T_50722_level0_col5" class="col_heading level0 col5" >ipadSc_urls.num</th>
#       <th id="T_50722_level0_col6" class="col_heading level0 col6" >lang.num</th>
#       <th id="T_50722_level0_col7" class="col_heading level0 col7" >cont_rating</th>
#       <th id="T_50722_level0_col8" class="col_heading level0 col8" >user_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50722_level0_row0" class="row_heading level0 row0" >size_bytes</th>
#       <td id="T_50722_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_50722_row0_col1" class="data row0 col1" >0.18</td>
#       <td id="T_50722_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_50722_row0_col3" class="data row0 col3" >0.01</td>
#       <td id="T_50722_row0_col4" class="data row0 col4" >-0.12</td>
#       <td id="T_50722_row0_col5" class="data row0 col5" >0.15</td>
#       <td id="T_50722_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_50722_row0_col7" class="data row0 col7" >0.14</td>
#       <td id="T_50722_row0_col8" class="data row0 col8" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_50722_level0_row1" class="row_heading level0 row1" >price</th>
#       <td id="T_50722_row1_col0" class="data row1 col0" >0.18</td>
#       <td id="T_50722_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_50722_row1_col2" class="data row1 col2" >-0.04</td>
#       <td id="T_50722_row1_col3" class="data row1 col3" >-0.02</td>
#       <td id="T_50722_row1_col4" class="data row1 col4" >-0.12</td>
#       <td id="T_50722_row1_col5" class="data row1 col5" >0.07</td>
#       <td id="T_50722_row1_col6" class="data row1 col6" >-0.01</td>
#       <td id="T_50722_row1_col7" class="data row1 col7" >-0.03</td>
#       <td id="T_50722_row1_col8" class="data row1 col8" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_50722_level0_row2" class="row_heading level0 row2" >rating_count_tot</th>
#       <td id="T_50722_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_50722_row2_col1" class="data row2 col1" >-0.04</td>
#       <td id="T_50722_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_50722_row2_col3" class="data row2 col3" >0.16</td>
#       <td id="T_50722_row2_col4" class="data row2 col4" >0.01</td>
#       <td id="T_50722_row2_col5" class="data row2 col5" >0.02</td>
#       <td id="T_50722_row2_col6" class="data row2 col6" >0.14</td>
#       <td id="T_50722_row2_col7" class="data row2 col7" >0.01</td>
#       <td id="T_50722_row2_col8" class="data row2 col8" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_50722_level0_row3" class="row_heading level0 row3" >rating_count_ver</th>
#       <td id="T_50722_row3_col0" class="data row3 col0" >0.01</td>
#       <td id="T_50722_row3_col1" class="data row3 col1" >-0.02</td>
#       <td id="T_50722_row3_col2" class="data row3 col2" >0.16</td>
#       <td id="T_50722_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_50722_row3_col4" class="data row3 col4" >0.04</td>
#       <td id="T_50722_row3_col5" class="data row3 col5" >0.02</td>
#       <td id="T_50722_row3_col6" class="data row3 col6" >0.01</td>
#       <td id="T_50722_row3_col7" class="data row3 col7" >0.00</td>
#       <td id="T_50722_row3_col8" class="data row3 col8" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_50722_level0_row4" class="row_heading level0 row4" >sup_devices.num</th>
#       <td id="T_50722_row4_col0" class="data row4 col0" >-0.12</td>
#       <td id="T_50722_row4_col1" class="data row4 col1" >-0.12</td>
#       <td id="T_50722_row4_col2" class="data row4 col2" >0.01</td>
#       <td id="T_50722_row4_col3" class="data row4 col3" >0.04</td>
#       <td id="T_50722_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_5

# %%
pd.plotting.scatter_matrix(data, c=data[target_col], figsize=(15, 15), marker='o',
                        hist_kwds={'bins': 20}, s=10, alpha=.8)
None

# %% [markdown]
# **Упражнение**: Мы только что посмотрели на данные, какой из посмотренных графиков говорит, что мы вряд ли сможем сделать хорошую модель?
# > Ответ:

# %% [markdown]
# ## Подготовка данных
#
# ### Очистка
#
# Данные достаточно чистые, в них вряд ли есть какие-то ошибки и не получается с первого взгляда найти выбросы (outliers). Поэтому и очищать особо нечего. Но в реальной жизни, ваши данные скорее всего будут полны мусора.
#
# Чаще всего нам пришлось бы убирать выбросы, исправлять очевидные ошибки итд.

# %% [markdown]
# ### Создание фичей
#
# Чем сложнее зависимость между фичей и таргетом, тем более сложная модель потребуется, чтобы эту зависимость использовать. Почему бы просто не выбрать семейство самых гибких моделей? Проблема в том, что без большого количества данных для обучения будет происходить overfit. Это значит, что модель выучит зависимости, которые случайно появились в обучающих из-за ограниченного размера выборки. Такая модель будет хорошо работать на обучающей выборке, но будет плохо справляться с реальной задачей.
#
# Используя человеческие знания об устройстве мира, мы можем упростить такую зависимость, создав новые фичи. На самом деле, можно даже не использовать человеческие знания, а просто применить какой-нибудь алгоритм. Например, если у нас есть фичи $x_1, x_2, ..., x_n$, то мы можем добавить новые фичи вида
# $$x_{newij} = x_i x_j, i \ne j$$
# и понадеяться, что это улучшит предсказания

# %% [markdown]
# В данном случае фичей мало, поэтому мы легко смогли посмотреть на них. Обычно фичей намного больше и построить такие графики для пар фичей не получится. Тогда в первую очередь можно посмотреть на корреляцию фичей с таргетом.

# %%
# Добавим категориальную фичу, которая говорит, бесплатное приложение или нет
data['is_free'] = data['price'] == 0
cat_cols.append('is_free')
data.head()
# Out:
#    size_bytes  price  rating_count_tot  rating_count_ver  sup_devices.num  \
# 0   100788224   3.99             21292                26               38
# 1   158578688   0.00            161065                26               37
# 2   100524032   0.00            188583              2822               37
# 3   128512000   0.00            262241               649               37
# 4    92774400   0.00            985920              5320               37
#
#    ipadSc_urls.num  lang.num  cont_rating   prime_genre  user_rating  is_free
# 0                5        10            4         Games          4.0    False
# 1                5        23            4  Productivity          4.0     True
# 2                5         3            4       Weather          3.5     True
# 3                5         9           12      Shopping          4.0     True
# 4                5        45            4     Reference          4.5     True

# %% [markdown]
# ### Работа с категориальными признаками
#
#
# Большинство алгоритмов не принимает категориальные фичи в чистом виде и нужно из как-то закодировать.
#
# Очень небольшое число алгоритмов МО умеет работать с категориальными признаками в чистом виде. Например, это делает библиотека для градиентного бустинга от Яндекса catboost. Внтури она применяет разные эвристики для кодирования признаков в числа.

# %% [markdown]
# #### One-hot-encoding
# Самый простой способ закодировать категориальные фичи - one hot encoding. Представьте, что у нас есть категориальная фича prime_genre с возможными значениями
# > ['Games', 'Entertainment', 'Education', 'Photo & Video']
#
# мы можем создать 4 новые бинарные фичи для каждого из столбцов
#
# > 'Entertaiment' -> [0, 1, 0, 0]
#
# В pandas очень удобно использовать get_dummies для one-hot-encoding

# %%
a = pd.DataFrame.from_dict({'categorical': ['a', 'b', 'a', 'c']})
a
# Out:
#   categorical
# 0           a
# 1           b
# 2           a
# 3           c

# %%
pd.get_dummies(a, dtype='int')
# Out:
#    categorical_a  categorical_b  categorical_c
# 0              1              0              0
# 1              0              1              0
# 2              1              0              0
# 3              0              0              1

# %%
# Задание: Теперь добавьте в датафрейм колонки для всех категориальных фичей и обновите список категориальных фичей
data = pd.get_dummies(data, columns=cat_cols)

# %%
cat_cols_new = []
for col_name in cat_cols:
    cat_cols_new.extend(filter(lambda x: x.startswith(col_name), data.columns))
cat_cols = cat_cols_new

# %% [markdown]
# ### Масштабирование признаков
#
# Как мы говорили в лекции часто необходимо привести все признаки к одному масштабу. Для этого в sklearn есть специальный Transformer -- StandardScaler и MinMaxScaler.
#
# StandardScaler во время .fit() для каждого признака $x_i$ считает среднее $\mu_i$ и стандартное отклонение $\sigma_i$ на обучающем датасете. Во время .transform() к каждому признаку применяется:
#
# $$\mathbf{x_i}^{\text{new}} = \frac{\mathbf{x_i} - \mu_i}{\sigma_i}$$
#
#
# MinMaxScaler во время .fit() для каждого признака $x_i$ считает минимум $x_{i, \text{min}}$ и максимум $x_{i, \text{max}}$ на обучающем датасете. Во время .transform() к каждому признаку применяется:
#
# $$\mathbf{x_i}^{\text{new}} = \frac{\mathbf{x_i} - x_{i, \text{min}}}{x_{i, \text{max}} - x_{i, \text{min}}}$$
